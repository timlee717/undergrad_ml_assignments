# %% [markdown]
# # Assignment 3: Linear Models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
import statsmodels.formula.api as smf

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, make_scorer

plt.rcParams["figure.figsize"] = (8, 5)
pd.set_option("display.max_columns", 100)
pd.set_option("display.float_format", lambda x: f"{x:,.4f}")

# %% [markdown]
# ## Q1. Conceptual questions
#
# ### 1. What makes a model “linear”? “Linear” in what?
#
# A model is called **linear** when it is linear in the **parameters/coefficient terms**, not necessarily linear in the raw variables themselves. For example,
#
# \[
# y = \beta_0 + \beta_1 x + \beta_2 x^2 + u
# \]
#
# is still a linear model because the coefficients \(\beta_0, \beta_1, \beta_2\) enter linearly.
# So “linear” refers to **linearity in the unknown coefficients**, not whether the graph must be a straight line in \(x\).
#
# ### 2. How do you interpret the coefficient for a dummy/one-hot-encoded variable?
#
# A dummy-variable coefficient measures the difference in the predicted outcome between that category and the **omitted baseline category**, holding the other regressors fixed.
#
# If the regression includes an intercept and you create dummy variables for categories, you usually **drop one category** to avoid the dummy-variable trap. Then:
#
# - the intercept is the mean for the omitted/reference group
# - each dummy coefficient is how much that group differs from the omitted group
#
# If instead you keep all category dummies and drop the intercept, then each dummy coefficient is the mean outcome for that group itself.
#
# ### 3. Can linear regression be used for classification? Explain why, or why not.
#
# Linear regression can technically be used with a 0/1 outcome, but it is usually **not the best choice for classification**. The main problem is that linear regression can predict values below 0 or above 1, which do not make sense as probabilities. Also, the relationship between predictors and a binary outcome is often not well modeled by a straight-line conditional mean over the whole range.
#
# That said, the **linear probability model** can still be useful because it is simple and its coefficients are easy to interpret as changes in probability. But for many classification tasks, logistic regression is preferred because predicted probabilities are constrained to lie between 0 and 1.
#
# ### 4. What are signs that your linear model is over-fitting?
#
# Signs of over-fitting include:
#
# - very strong performance on the training set but much worse performance on the test set
# - cross-validation error increasing as the model becomes more complex
# - unstable coefficients that change a lot across samples
# - a model that seems to be fitting random noise rather than the main pattern
# - residual plots or predictions that look overly sensitive to a few observations
#
# In general, over-fitting happens when the model is too flexible relative to the amount of information in the data.
#
# ### 5. Clearly explain multicollinearity using the two-stage least squares idea.
#
# Multicollinearity means one explanatory variable can be explained very well by the others. A helpful way to see this is through a two-stage idea:
#
# 1. Regress one regressor, say \(x_1\), on the other regressors.
# 2. Look at the residual part of \(x_1\), which is the variation in \(x_1\) not explained by the others.
#
# OLS identifies the coefficient on \(x_1\) using only that leftover variation. If \(x_1\) is highly collinear with the other regressors, then there is very little leftover variation. That makes the coefficient estimate noisy and its standard error large.
#
# So multicollinearity does **not** necessarily bias OLS, but it makes it harder to separate the individual effect of one regressor from the effects of the others.
#
# ### 6. How can you incorporate nonlinear relationships into your analysis?
#
# You can include nonlinear relationships while still using a linear model by transforming the regressors. Common approaches include:
#
# - polynomial terms such as \(x^2\), \(x^3\)
# - logs, square roots, or inverse transformations
# - interaction terms
# - piecewise linear functions or splines
#
# For example,
#
# \[
# y = \beta_0 + \beta_1 x + \beta_2 x^2 + u
# \]
#
# allows the effect of \(x\) on \(y\) to vary with the level of \(x\), even though the model is still linear in the coefficients.
#
# ### 7. What is the interpretation of the slope coefficient in a linear regression?
#
# The slope coefficient gives the predicted change in the dependent variable for a one-unit increase in the regressor, holding the other regressors fixed.
#
# For example, in
#
# \[
# y = \beta_0 + \beta_1 x + u,
# \]
#
# \(\beta_1\) means that when \(x\) goes up by 1 unit, the predicted value of \(y\) changes by \(\beta_1\) units on average.
#
# ### 8. Compare the train/test split and k-fold cross validation.
#
# A **train/test split** divides the data once into a training set and a testing set. It is simple and fast, but the evaluation can depend heavily on the particular split you happened to choose.
#
# In **k-fold cross validation**, the data are divided into \(k\) roughly equal parts. The model is trained \(k\) times, each time leaving out one fold for validation and using the other \(k-1\) folds for training. The results are then averaged.
#
# Compared with a single train/test split, k-fold cross validation usually gives a more stable and reliable estimate of out-of-sample performance because it uses the data more efficiently.
#
# ### 9. How is the k in k-fold cross validation typically selected?
#
# The value of \(k\) is usually chosen as a compromise between computation time and stability:
#
# - smaller \(k\) (like 5) is faster
# - larger \(k\) (like 10) often gives a more stable estimate of performance
#
# In practice, **5-fold** and **10-fold cross validation** are the most common choices. Ten-fold cross validation is often used because it balances bias, variance, and computational cost fairly well.

# %% [markdown]
# ## Q2. Airbnb-style NYC neighborhood data

# %%
q2 = pd.read_csv("./data/Q1_clean.csv")
q2.head()
# Out:
#    Price  Review Scores Rating Neighbourhood  Property Type        Room Type
# 0    549               96.0000      Manhattan     Apartment     Private room
# 1    149              100.0000       Brooklyn     Apartment  Entire home/apt
# 2    250              100.0000      Manhattan     Apartment  Entire home/apt
# 3     90               94.0000       Brooklyn     Apartment     Private room
# 4    270               90.0000      Manhattan     Apartment  Entire home/apt

# %%
# Clean column names a bit while preserving the original information
q2.columns = [c.strip().replace(" ", "_") for c in q2.columns]

# Try to standardize likely column names
rename_map = {}
for c in q2.columns:
    lc = c.lower()
    if "price" in lc and "night" in lc:
        rename_map[c] = "price"
    elif lc == "price":
        rename_map[c] = "price"
    elif "review" in lc and "rating" in lc:
        rename_map[c] = "review_score"
    elif "neighbourhood" in lc or "neighborhood" in lc:
        rename_map[c] = "neighbourhood"
q2 = q2.rename(columns=rename_map)

required_cols_q2 = ["price", "review_score", "neighbourhood"]
print("Columns after renaming:", q2.columns.tolist())
print("Missing required columns:", [c for c in required_cols_q2 if c not in q2.columns])
# Out:
# Columns after renaming: ['price', 'review_score', 'neighbourhood', 'Property_Type', 'Room_Type']
# Missing required columns: []

# %%
# Basic cleaning
q2 = q2[required_cols_q2].dropna().copy()
q2["price"] = pd.to_numeric(q2["price"], errors="coerce")
q2["review_score"] = pd.to_numeric(q2["review_score"], errors="coerce")
q2 = q2.dropna().copy()
q2["log_price"] = np.log(q2["price"])

q2.head()
# Out:
#    price  review_score neighbourhood  log_price
# 0    549       96.0000     Manhattan     6.3081
# 1    149      100.0000      Brooklyn     5.0039
# 2    250      100.0000     Manhattan     5.5215
# 3     90       94.0000      Brooklyn     4.4998
# 4    270       90.0000     Manhattan     5.5984

# %% [markdown]
# ### Q2.1 Average prices and scores by neighbourhood

# %%
q2_summary = (
    q2.groupby("neighbourhood")
      .agg(
          avg_price=("price", "mean"),
          median_price=("price", "median"),
          avg_review_score=("review_score", "mean"),
          n=("price", "size")
      )
      .sort_values("avg_price", ascending=False)
)

q2_summary
# Out:
#                avg_price  median_price  avg_review_score      n
# neighbourhood
# Manhattan       183.6643      150.0000           91.8015  11763
# Staten Island   146.1667       71.0000           90.8438     96
# Brooklyn        127.7474      100.0000           92.3635   8487
# Queens           96.8572       80.0000           91.5491   1590
# Bronx            75.2765       60.0000           91.6544    217

# %%
most_expensive_borough = q2_summary.index[0]
most_expensive_price = q2_summary.iloc[0]["avg_price"]

print(f"The most expensive borough on average is {most_expensive_borough} with average price {most_expensive_price:,.2f}.")
# Out:
# The most expensive borough on average is Manhattan with average price 183.66.

# %% [markdown]
# ### Q2.2 Kernel density plots of price and log price by neighbourhood

# %%
fig, ax = plt.subplots()
for name, grp in q2.groupby("neighbourhood"):
    grp["price"].plot(kind="kde", ax=ax, label=name)
ax.set_title("Kernel Density of Price by Neighbourhood")
ax.set_xlabel("Price")
ax.legend()
plt.show()

fig, ax = plt.subplots()
for name, grp in q2.groupby("neighbourhood"):
    grp["log_price"].plot(kind="kde", ax=ax, label=name)
ax.set_title("Kernel Density of Log Price by Neighbourhood")
ax.set_xlabel("Log Price")
ax.legend()
plt.show()

# %% [markdown]
# ### Q2.3 Regress price on neighbourhood dummies

# %%
# With intercept + drop first category
mod_q2_neigh = smf.ols("price ~ C(neighbourhood)", data=q2).fit()
print(mod_q2_neigh.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.046
# Method:                 Least Squares   F-statistic:                     268.9
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):          4.43e-226
# Time:                        00:48:54   Log-Likelihood:            -1.4174e+05
# No. Observations:               22153   AIC:                         2.835e+05
# Df Residuals:                   22148   BIC:                         2.835e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
# Compare regression coefficients to group means
baseline = q2["neighbourhood"].astype("category").cat.categories[0]
baseline_mean = q2.loc[q2["neighbourhood"] == baseline, "price"].mean()

coef_table = pd.DataFrame({
    "coefficient": mod_q2_neigh.params
})

print("Baseline category (omitted group):", baseline)
print("Baseline mean price:", baseline_mean)

coef_table
# Out:
# Baseline category (omitted group): Bronx
# Baseline mean price: 75.27649769585254
#                                    coefficient
# Intercept                              75.2765
# C(neighbourhood)[T.Brooklyn]           52.4709
# C(neighbourhood)[T.Manhattan]         108.3878
# C(neighbourhood)[T.Queens]             21.5807
# C(neighbourhood)[T.Staten Island]      70.8902

# %% [markdown]
# With an intercept and one omitted category:
#
# - the intercept equals the average price for the baseline neighbourhood
# - each neighborhood coefficient equals that neighbourhood's mean price minus the baseline mean
#
# So the regression is just re-expressing the group means from the summary table in dummy-variable form.

# %% [markdown]
# ### Q2.4 Regress price on review scores

# %%
mod_q2_review = smf.ols("price ~ review_score", data=q2).fit()
print(mod_q2_review.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     81.92
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):           1.53e-19
# Time:                        00:48:54   Log-Likelihood:            -1.4222e+05
# No. Observations:               22153   AIC:                         2.844e+05
# Df Residuals:                   22151   BIC:                         2.845e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       60.8784     10.423      5.841      0.000      40.448      81.309
# ...

# %%
b0 = mod_q2_review.params["Intercept"]
b1 = mod_q2_review.params["review_score"]

print(f"Intercept: {b0:,.4f}")
print(f"Slope on review_score: {b1:,.4f}")
print()
print(
    f"Interpretation: a 1-point increase in review score is associated with an average change "
    f"of {b1:,.4f} in price per night."
)
# Out:
# Intercept: 60.8784
# Slope on review_score: 1.0208
#
# Interpretation: a 1-point increase in review score is associated with an average change of 1.0208 in price per night.

# %% [markdown]
# ### Q2.5 Regress price on neighbourhood and review scores

# %%
mod_q2_both = smf.ols("price ~ C(neighbourhood) + review_score", data=q2).fit()
print(mod_q2_both.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     235.3
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):          1.21e-245
# Time:                        00:48:54   Log-Likelihood:            -1.4169e+05
# No. Observations:               22153   AIC:                         2.834e+05
# Df Residuals:                   22147   BIC:                         2.834e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
comparison_q2 = pd.DataFrame({
    "review_only": mod_q2_review.params.reindex(mod_q2_review.params.index),
    "neighbourhood_plus_review": mod_q2_both.params.reindex(mod_q2_review.params.index)
})
comparison_q2
# Out:
#               review_only  neighbourhood_plus_review
# Intercept         60.8784                   -23.8126
# review_score       1.0208                     1.0811

# %% [markdown]
# After adding neighbourhood controls, the review-score slope shows the relationship between review score and price **holding neighbourhood fixed**.
# If the slope changes relative to the simple regression, that means part of the original relationship was coming from differences across neighborhoods rather than only within neighborhoods.

# %% [markdown]
# ### Q2.6 Separate slope for review score in each neighbourhood

# %%
mod_q2_interact = smf.ols("price ~ C(neighbourhood) * review_score", data=q2).fit()
print(mod_q2_interact.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     178.4
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):               0.00
# Time:                        00:48:54   Log-Likelihood:            -1.4149e+05
# No. Observations:               22153   AIC:                         2.830e+05
# Df Residuals:                   22143   BIC:                         2.831e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Compute implied slopes by neighbourhood
cats = q2["neighbourhood"].astype("category").cat.categories.tolist()
base = cats[0]

slopes = {}
base_slope = mod_q2_interact.params["review_score"]
slopes[base] = base_slope

for c in cats[1:]:
    term = f"C(neighbourhood)[T.{c}]:review_score"
    slopes[c] = base_slope + mod_q2_interact.params.get(term, 0)

pd.Series(slopes, name="review_score_slope_by_neighbourhood").sort_values()
# Out:
# Staten Island   -31.2574
# Queens            0.5020
# Bronx             0.5743
# Manhattan         1.3040
# Brooklyn          1.3155
# Name: review_score_slope_by_neighbourhood, dtype: float64

# %% [markdown]
# ### Q2.7 Cross-validation for models in parts 4, 5, and 6

# %%
def rmse_cv_formula(formula, data, k=10):
    y = data["price"].values
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    rmses = []
    for train_idx, test_idx in kf.split(data):
        train = data.iloc[train_idx]
        test = data.iloc[test_idx]
        fit = smf.ols(formula, data=train).fit()
        preds = fit.predict(test)
        rmse = np.sqrt(np.mean((test["price"] - preds) ** 2))
        rmses.append(rmse)
    return np.mean(rmses), np.std(rmses)

cv_results_q2 = pd.DataFrame({
    "model": [
        "price ~ review_score",
        "price ~ C(neighbourhood) + review_score",
        "price ~ C(neighbourhood) * review_score"
    ],
    "mean_rmse": [
        rmse_cv_formula("price ~ review_score", q2)[0],
        rmse_cv_formula("price ~ C(neighbourhood) + review_score", q2)[0],
        rmse_cv_formula("price ~ C(neighbourhood) * review_score", q2)[0]
    ],
    "sd_rmse": [
        rmse_cv_formula("price ~ review_score", q2)[1],
        rmse_cv_formula("price ~ C(neighbourhood) + review_score", q2)[1],
        rmse_cv_formula("price ~ C(neighbourhood) * review_score", q2)[1]
    ]
}).sort_values("mean_rmse")

cv_results_q2
# Out:
#                                      model  mean_rmse  sd_rmse
# 1  price ~ C(neighbourhood) + review_score   139.0102  41.7969
# 2  price ~ C(neighbourhood) * review_score   139.9991  41.5140
# 0                     price ~ review_score   142.7594  41.2422

# %% [markdown]
# The model with the **lowest cross-validated RMSE** is the best out-of-sample predictor among these three.
# If the interaction model does not improve RMSE much, then allowing different review-score slopes by neighborhood may not be worth the extra complexity.

# %% [markdown]
# ## Q3. Car price case study

# %%
cars = pd.read_csv("./data/cars_hw.csv")
cars.head()
# Out:
#    Unnamed: 0        Make  Make_Year   Color  Body_Type  Mileage_Run  \
# 0           1  Volkswagen       2017  silver      sedan        44611
# 1           2     Hyundai       2016     red  crossover        20305
# 2           3       Honda       2019   white        suv        29540
# 3           4     Renault       2017  bronze  hatchback        35680
# 4           5     Hyundai       2017  orange  hatchback        25126
#
#   No_of_Owners  Seating_Capacity Fuel_Type Transmission Transmission_Type  \
# 0          1st                 5    diesel      7-Speed         Automatic
# 1          1st                 5    petrol      5-Speed            Manual
# 2          2nd                 5    petrol      5-Speed            Manual
# 3          1st                 5    petrol      5-Speed            Manual
# 4          1st                 5    petrol      5-Speed            Manual
#
#     Price
# 0  657000
# 1  682000
# 2  793000
# 3  414000
# 4  515000

# %%
cars.columns = [c.strip().replace(" ", "_") for c in cars.columns]
rename_map = {}
for c in cars.columns:
    lc = c.lower()
    if lc == "price":
        rename_map[c] = "Price"
    elif "seating" in lc and "capacity" in lc:
        rename_map[c] = "Seating_Capacity"
    elif "body" in lc and "type" in lc:
        rename_map[c] = "Body_Type"
    elif "make" in lc and "year" in lc:
        rename_map[c] = "Make_Year"
cars = cars.rename(columns=rename_map)

required_cols_q3 = ["Price", "Seating_Capacity", "Body_Type", "Make_Year"]
print("Columns after renaming:", cars.columns.tolist())
print("Missing required columns:", [c for c in required_cols_q3 if c not in cars.columns])

cars = cars[required_cols_q3].dropna().copy()
cars["Price"] = pd.to_numeric(cars["Price"], errors="coerce")
cars["Seating_Capacity"] = pd.to_numeric(cars["Seating_Capacity"], errors="coerce")
cars["Make_Year"] = pd.to_numeric(cars["Make_Year"], errors="coerce")
cars = cars.dropna().copy()

cars.head()
# Out:
# Columns after renaming: ['Unnamed:_0', 'Make', 'Make_Year', 'Color', 'Body_Type', 'Mileage_Run', 'No_of_Owners', 'Seating_Capacity', 'Fuel_Type', 'Transmission', 'Transmission_Type', 'Price']
# Missing required columns: []
#     Price  Seating_Capacity  Body_Type  Make_Year
# 0  657000                 5      sedan       2017
# 1  682000                 5  crossover       2016
# 2  793000                 5        suv       2019
# 3  414000                 5  hatchback       2017
# 4  515000                 5  hatchback       2017

# %% [markdown]
# ### Q3.1 Summarize price and plot densities

# %%
cars["Price"].describe()
# Out:
# count         976.0000
# mean      741,019.4672
# std       367,323.3755
# min       188,000.0000
# 25%       475,750.0000
# 50%       666,500.0000
# 75%       883,000.0000
# max     2,941,000.0000
# Name: Price, dtype: float64

# %%
fig, ax = plt.subplots()
cars["Price"].plot(kind="kde", ax=ax)
ax.set_title("Kernel Density Plot of Car Price")
ax.set_xlabel("Price")
plt.show()

# %%
body_summary = cars.groupby("Body_Type")["Price"].describe().sort_values("mean", ascending=False)
body_summary
# Out:
#              count           mean          std          min          25%  \
# Body_Type
# suv       206.0000 1,176,495.1456 417,479.0282 559,000.0000 860,000.0000
# sedan     227.0000   809,784.1410 286,736.7701 368,000.0000 598,000.0000
# crossover  21.0000   705,095.2381  72,849.7802 608,000.0000 638,000.0000
# muv        38.0000   626,421.0526 184,093.4885 328,000.0000 489,750.0000
# hatchback 484.0000   533,977.2727 173,086.7298 188,000.0000 401,750.0000
#
#                      50%            75%            max
# Body_Type
# suv       1,065,000.0000 1,491,250.0000 2,100,000.0000
# sedan       772,000.0000   968,500.0000 2,941,000.0000
# crossover   706,000.0000   749,000.0000   883,000.0000
# muv         621,500.0000   738,500.0000 1,091,000.0000
# hatchback   509,000.0000   661,000.0000 1,107,000.0000

# %%
fig, ax = plt.subplots()
for name, grp in cars.groupby("Body_Type"):
    grp["Price"].plot(kind="kde", ax=ax, label=name)
ax.set_title("Grouped Kernel Density Plot of Price by Body Type")
ax.set_xlabel("Price")
ax.legend()
plt.show()

# %% [markdown]
# From the `groupby().describe()` table:
#
# - the body type with the highest **mean** price is the most expensive on average
# - the body type with the largest **standard deviation** has the most variance in prices

# %% [markdown]
# ### Q3.2 Regress price on seating capacity

# %%
mod_q3_seats_linear = smf.ols("Price ~ Seating_Capacity", data=cars).fit()
print(mod_q3_seats_linear.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.075
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):             0.0245
# Time:                        00:49:01   Log-Likelihood:                -13888.
# No. Observations:                 976   AIC:                         2.778e+04
# Df Residuals:                     974   BIC:                         2.779e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept          4.39e+05   1.35e+05      3.263      0.001    1.75e+05    7.03e+05
# ...

# %%
seat_slope = mod_q3_seats_linear.params["Seating_Capacity"]
print(
    f"Slope on Seating_Capacity: {seat_slope:,.4f}. "
    f"This means one additional seat is associated with an average change of {seat_slope:,.4f} in price."
)
# Out:
# Slope on Seating_Capacity: 59,267.9980. This means one additional seat is associated with an average change of 59,267.9980 in price.

# %%
mod_q3_seats_cat = smf.ols("Price ~ C(Seating_Capacity)", data=cars).fit()
print(mod_q3_seats_cat.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     5.397
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):           0.000267
# Time:                        00:49:01   Log-Likelihood:                -13880.
# No. Observations:                 976   AIC:                         2.777e+04
# Df Residuals:                     971   BIC:                         2.779e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                  1.88e+05   3.64e+05      0.516      0.606   -5.26e+05    9.02e+05
# ...

# %%
seat_means = cars.groupby("Seating_Capacity")["Price"].mean().sort_index()
seat_means
# Out:
# Seating_Capacity
# 4     188,000.0000
# 5     734,483.8710
# 6   1,644,000.0000
# 7     923,948.7179
# 8     459,800.0000
# Name: Price, dtype: float64

# %% [markdown]
# To decide whether the relationship is roughly linear in seats, compare:
#
# - the linear-regression fit using one slope for seat count
# - the group means from the categorical specification
#
# If the average prices move in a fairly steady pattern as seats increase, then treating seats as numeric is reasonable. If the means jump around a lot, the linear specification may be too restrictive.

# %% [markdown]
# ### Q3.3 Create age variable and use 10-fold CV to choose polynomial degree

# %%
current_year = pd.Timestamp.today().year
cars["Age"] = current_year - cars["Make_Year"]
cars[["Make_Year", "Age"]].head()
# Out:
#    Make_Year  Age
# 0       2017    9
# 1       2016   10
# 2       2019    7
# 3       2017    9
# 4       2017    9

# %%
degree_results = []

X_age = cars[["Age"]].values
y_price = cars["Price"].values
kf = KFold(n_splits=10, shuffle=True, random_state=42)

for degree in range(1, 11):
    model = Pipeline([
        ("poly", PolynomialFeatures(degree=degree, include_bias=False)),
        ("lr", LinearRegression())
    ])
    neg_mse_scores = cross_val_score(
        model, X_age, y_price,
        cv=kf,
        scoring="neg_mean_squared_error"
    )
    rmse = np.sqrt(-neg_mse_scores.mean())
    degree_results.append({"degree": degree, "cv_rmse": rmse})

degree_results = pd.DataFrame(degree_results).sort_values("cv_rmse")
degree_results
# Out:
#    degree      cv_rmse
# 6       7 307,715.7311
# 9      10 307,924.5264
# 7       8 308,182.0527
# 8       9 308,231.4646
# 4       5 308,650.3451
# 5       6 308,802.4585
# 3       4 310,201.6090
# 2       3 311,035.6970
# 0       1 312,053.2776
# 1       2 312,082.8511

# %%
best_degree = int(degree_results.iloc[0]["degree"])
print(f"Optimal polynomial degree by 10-fold CV: {best_degree}")
# Out:
# Optimal polynomial degree by 10-fold CV: 7

# %% [markdown]
# ### Q3.4 Plot actual and model-predicted price against age

# %%
best_model = Pipeline([
    ("poly", PolynomialFeatures(degree=best_degree, include_bias=False)),
    ("lr", LinearRegression())
])
best_model.fit(X_age, y_price)

age_grid = np.linspace(cars["Age"].min(), cars["Age"].max(), 200).reshape(-1, 1)
pred_grid = best_model.predict(age_grid)

fig, ax = plt.subplots()
ax.scatter(cars["Age"], cars["Price"], alpha=0.4, label="Observed data")
ax.plot(age_grid, pred_grid, linewidth=2, label=f"Predicted price (degree={best_degree})")
ax.set_title("Price vs Age with Model Predictions")
ax.set_xlabel("Age")
ax.set_ylabel("Price")
ax.legend()
plt.show()

# %% [markdown]
# Use the graph to judge fit:
#
# - if the fitted curve captures the main decline or curvature in prices as cars age, the model is working well
# - if the line misses clear patterns or wiggles too much, the selected degree may under-fit or over-fit

# %% [markdown]
# ## Q4. Heart transplant case study

# %%
heart = pd.read_csv("./data/heart_hw.csv")
heart.head()
# Out:
#    Unnamed: 0  age transplant  y
# 0           1   53    control  0
# 1           2   43    control  0
# 2           3   52    control  0
# 3           4   52    control  0
# 4           5   54    control  0

# %%
heart.columns = [c.strip().replace(" ", "_") for c in heart.columns]

rename_map = {}
for c in heart.columns:
    lc = c.lower()
    if lc == "y":
        rename_map[c] = "y"
    elif lc == "age":
        rename_map[c] = "age"
    elif "transplant" in lc:
        rename_map[c] = "transplant"
heart = heart.rename(columns=rename_map)

required_cols_q4 = ["y", "age", "transplant"]
print("Columns after renaming:", heart.columns.tolist())
print("Missing required columns:", [c for c in required_cols_q4 if c not in heart.columns])

heart = heart[required_cols_q4].dropna().copy()
heart["y"] = pd.to_numeric(heart["y"], errors="coerce")
heart["age"] = pd.to_numeric(heart["age"], errors="coerce")
heart = heart.dropna().copy()

heart["transplant"] = heart["transplant"].astype(str).str.lower().str.strip()
heart.head()
# Out:
# Columns after renaming: ['Unnamed:_0', 'age', 'transplant', 'y']
# Missing required columns: []
#    y  age transplant
# 0  0   53    control
# 1  0   43    control
# 2  0   52    control
# 3  0   52    control
# 4  0   54    control

# %% [markdown]
# ### Q4.1 Survival proportions and ATE

# %%
survival_rates = heart.groupby("transplant")["y"].mean()
survival_rates
# Out:
# transplant
# control     0.1176
# treatment   0.3478
# Name: y, dtype: float64

# %%
control_rate = survival_rates.loc["control"]
treatment_rate = survival_rates.loc["treatment"]
ate = treatment_rate - control_rate

print(f"Control survival proportion:   {control_rate:.4f}")
print(f"Treatment survival proportion: {treatment_rate:.4f}")
print(f"ATE (treatment - control):     {ate:.4f}")
# Out:
# Control survival proportion:   0.1176
# Treatment survival proportion: 0.3478
# ATE (treatment - control):     0.2302

# %% [markdown]
# ### Q4.2 Regress y on transplant

# %%
mod_q4_basic = smf.ols("y ~ C(transplant)", data=heart).fit()
print(mod_q4_basic.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     6.354
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):             0.0133
# Time:                        00:49:01   Log-Likelihood:                -59.591
# No. Observations:                 103   AIC:                             123.2
# Df Residuals:                     101   BIC:                             128.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.1176      0.075      1.574      0.119      -0.031       0.266
# ...

# %% [markdown]
# With an intercept and one omitted category:
#
# - the intercept is the average survival probability for the baseline group
# - the transplant coefficient is the difference in mean survival probability between treatment and control
#
# So this regression reproduces the same comparison as the treatment-control average from part 1.

# %% [markdown]
# ### Q4.3 Regress y on transplant and age

# %%
mod_q4_age = smf.ols("y ~ C(transplant) + age", data=heart).fit()
print(mod_q4_age.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.130
# Method:                 Least Squares   F-statistic:                     8.602
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):           0.000357
# Time:                        00:49:01   Log-Likelihood:                -54.558
# No. Observations:                 103   AIC:                             115.1
# Df Residuals:                     100   BIC:                             123.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                      0.7020      0.196      3.583      0.001       0.313       1.091
# ...

# %%
age_grid = np.linspace(heart["age"].min(), heart["age"].max(), 200)

pred_control = pd.DataFrame({"transplant": ["control"] * len(age_grid), "age": age_grid})
pred_treat = pd.DataFrame({"transplant": ["treatment"] * len(age_grid), "age": age_grid})

yhat_control = mod_q4_age.predict(pred_control)
yhat_treat = mod_q4_age.predict(pred_treat)

fig, ax = plt.subplots()
ax.plot(age_grid, yhat_control, label="Predicted survival: control")
ax.plot(age_grid, yhat_treat, label="Predicted survival: treatment")
ax.axhline(ate, linestyle="--", label="ATE from part 1")
ax.set_title("Predicted Survival by Age: Model with Transplant and Age")
ax.set_xlabel("Age")
ax.set_ylabel("Predicted probability of survival")
ax.legend()
plt.show()

# %% [markdown]
# Interpretation for this model:
#
# - the intercept is the predicted survival probability for the baseline transplant group when age = 0
# - the age slope is the change in predicted survival probability associated with a one-year increase in age, holding transplant status fixed
# - the transplant coefficient is the treatment-control difference holding age fixed
#
# Because age = 0 is not meaningful here, the intercept is mostly a mathematical anchor. The slopes and predicted values across realistic ages matter more.

# %% [markdown]
# ### Q4.4 Add transplant, age, and transplant × age

# %%
mod_q4_interact = smf.ols("y ~ C(transplant) * age", data=heart).fit()
print(mod_q4_interact.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.147
# Method:                 Least Squares   F-statistic:                     6.839
# Date:                Fri, 20 Mar 2026   Prob (F-statistic):           0.000310
# Time:                        00:49:02   Log-Likelihood:                -53.033
# No. Observations:                 103   AIC:                             114.1
# Df Residuals:                      99   BIC:                             124.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %%
yhat_control_i = mod_q4_interact.predict(pred_control)
yhat_treat_i = mod_q4_interact.predict(pred_treat)

fig, ax = plt.subplots()
ax.plot(age_grid, yhat_control_i, label="Predicted survival: control")
ax.plot(age_grid, yhat_treat_i, label="Predicted survival: treatment")
ax.axhline(ate, linestyle="--", label="ATE from part 1")
ax.set_title("Predicted Survival by Age: Interaction Model")
ax.set_xlabel("Age")
ax.set_ylabel("Predicted probability of survival")
ax.legend()
plt.show()

# %%
impact_by_age = yhat_treat_i - yhat_control_i

fig, ax = plt.subplots()
ax.plot(age_grid, impact_by_age, label="Predicted treatment effect by age")
ax.axhline(ate, linestyle="--", label="ATE from part 1")
ax.set_title("Predicted Transplant Effect by Age")
ax.set_xlabel("Age")
ax.set_ylabel("Treatment effect on predicted survival")
ax.legend()
plt.show()

# %% [markdown]
# Allowing the interaction means the effect of transplant is no longer forced to be the same at every age.
# If the treatment-effect line changes with age, then the constant ATE from part 1 is hiding important heterogeneity across patients.

# %% [markdown]
# ### Q4.5 10-fold cross-validation

# %%
def rmse_cv_binary_formula(formula, data, k=10):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    rmses = []
    for train_idx, test_idx in kf.split(data):
        train = data.iloc[train_idx]
        test = data.iloc[test_idx]
        fit = smf.ols(formula, data=train).fit()
        preds = fit.predict(test)
        rmse = np.sqrt(np.mean((test["y"] - preds) ** 2))
        rmses.append(rmse)
    return np.mean(rmses), np.std(rmses)

cv_results_q4 = pd.DataFrame({
    "model": [
        "y ~ C(transplant)",
        "y ~ C(transplant) + age",
        "y ~ C(transplant) * age"
    ],
    "mean_rmse": [
        rmse_cv_binary_formula("y ~ C(transplant)", heart)[0],
        rmse_cv_binary_formula("y ~ C(transplant) + age", heart)[0],
        rmse_cv_binary_formula("y ~ C(transplant) * age", heart)[0]
    ],
    "sd_rmse": [
        rmse_cv_binary_formula("y ~ C(transplant)", heart)[1],
        rmse_cv_binary_formula("y ~ C(transplant) + age", heart)[1],
        rmse_cv_binary_formula("y ~ C(transplant) * age", heart)[1]
    ]
}).sort_values("mean_rmse")

cv_results_q4
# Out:
#                      model  mean_rmse  sd_rmse
# 2  y ~ C(transplant) * age     0.4130   0.0677
# 1  y ~ C(transplant) + age     0.4167   0.0603
# 0        y ~ C(transplant)     0.4365   0.0503

# %% [markdown]
# ### Q4.6 Concerns about using this model to prioritize transplant access
#
# I would be very cautious about deploying this kind of model for real transplant allocation. Some major concerns are:
#
# 1. **Selection bias / confounding:** People who receive transplants are not randomly assigned. Sicker or healthier patients may be more likely to receive treatment, so the estimated effect may not be causal.
# 2. **Fairness concerns:** A model could systematically disadvantage older patients or other groups if historical treatment patterns reflect inequities.
# 3. **Linear probability model limitations:** Predicted values can fall outside the 0 to 1 range, and the linear structure may oversimplify survival relationships.
# 4. **Small-data instability:** If the sample is not large, the estimated treatment effects can be noisy.
# 5. **Ethical deployment risk:** A predictive model should support clinical judgment, not replace it, especially in high-stakes medical decisions.
#
# So even if one model predicts reasonably well, that does not mean it should automatically be used to decide who gets treatment.
